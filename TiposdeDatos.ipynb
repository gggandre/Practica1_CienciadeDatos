# %%
type (42)
# Out:
# int

# %%
3+5
3-5
3*5
3/5
# Out:
# 0.6

# %%
5**3
# Out:
# 125

# %%
5//3
# Out:
# 1

# %%
5%3
# Out:
# 2

# %%
(3+5//4-2)-2**4+3*(7-2)
# Out:
# 1

# %%
5//4>3 or 2<5**2
# Out:
# True

# %%
1<2 and 5<2*4
# Out:
# True

# %%
"Yo soy " + "Tu hijo"
# Out:
# 'Yo soy Tu hijo'

# %%
"Ja"*4
# Out:
# 'JaJaJaJa'

# %%
3*5.37
# Out:
# 16.11

# %%
8/1.5
# Out:
# 5.333333333333333

# %%
+15
# Out:
# 15

# %%
"Son las" + str(15)
# Out:
# 'Son las15'

# %%
int(3.5)
# Out:
# 3

# %%
int("3")+12
# Out:
# 15

# %%
float(3)
# Out:
# 3.0

# %%
float("3.5")+12
# Out:
# 15.5
